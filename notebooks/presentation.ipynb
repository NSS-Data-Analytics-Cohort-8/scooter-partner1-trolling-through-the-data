# %% [markdown]
# <h1>Presentation Journal</h1>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster
from sqlalchemy import create_engine

database_name = 'scooters'
connection_string = f"postgresql://postgres:postgres@localhost:5432/{database_name}"

engine = create_engine(connection_string)

# Read in the bus stops data csv
bus_stops_df = pd.read_csv('../data/regional_transportation_authority_bus_stops.csv')

# Feet in miles constant
FEET_IN_MILES = 5280

# %% [markdown]
# <h3>Does it appear that scooters are used as "last mile" transportation from public transit hubs to work or school?</h3>

# %% [markdown]
# <h4>First, we need to query all of the trips into 1 dataframe</h4>

# %%
trips_query = """
select *
from trips
"""

trips_df = pd.read_sql(trips_query, engine)

# %% [markdown]
# <h4>Next, we will define a function that calculates the shortest distance between 2 coordinates.</h4>

# %%
def shortest_distance(start_latitude, start_longitude, end_latitude, end_longitude):
    """
    Calculating the distance between 2 coordinates using the haversine formula
    https://en.wikipedia.org/wiki/Haversine_formula
    https://stackoverflow.com/questions/4913349/haversine-formula-in-python-bearing-and-distance-between-two-gps-points
    """
    # We have to convert the latitudes and longitudes to radians for the formula to work
    start_latitude, start_longitude, end_latitude, end_longitude = map(
        np.radians,
        [start_latitude, start_longitude, end_latitude, end_longitude]
    )
                                                 
    # Now we build out the formula
    distance_longitude = end_longitude - start_longitude
    distance_latitude = end_latitude - start_latitude
    
    angle = np.sin(distance_latitude / 2) ** 2 + np.cos(start_latitude) * np.cos(end_latitude) * np.sin(distance_longitude / 2) ** 2
    central_angle = 2 * np.arcsin(np.sqrt(angle))
    km = 6371 * central_angle # The Earth is 6371 km in radius
    miles = km * 0.621371 # Converting to miles

    return miles

# %% [markdown]
# <h4>Now let's see the numbers on scooter trips under and over 1 mile. These will be used for later data discovery.</h4>

# %%
# Getting counts on trips that are less than 1 mile
trips_under_1_mile_df = trips_df[trips_df['tripdistance'] < FEET_IN_MILES]
trips_1_mile_or_more_df = trips_df[trips_df['tripdistance'] >= FEET_IN_MILES]
trips_under_500_feet_df = trips_df[trips_df['tripdistance'] < 500]

number_of_trips_under_1_mile = len(trips_under_1_mile_df)
number_of_trips_1_mile_or_more = len(trips_1_mile_or_more_df)
number_of_trips_under_500_feet = len(trips_under_500_feet_df)

# Getting the percentage of trips that are less than 1 mile
percentage_of_trips_under_1_mile = number_of_trips_under_1_mile / (number_of_trips_under_1_mile + number_of_trips_1_mile_or_more)
percentage_of_trips_1_mile_or_more = number_of_trips_1_mile_or_more / (number_of_trips_under_1_mile + number_of_trips_1_mile_or_more)

# Getting the percentage of trips that are less than 500 feet
percentage_of_trips_under_500_feet = number_of_trips_under_500_feet / (number_of_trips_under_1_mile + number_of_trips_1_mile_or_more)

print(f'The number of trips under 1 mile is {number_of_trips_under_1_mile} ({round(percentage_of_trips_under_1_mile * 100, 2)}%)')
print(f'The number of trips 1 mile or more is {number_of_trips_1_mile_or_more} ({round(percentage_of_trips_1_mile_or_more * 100, 2)}%)')
print(f'The number of trips under 500 feet is {number_of_trips_under_500_feet} ({round(percentage_of_trips_under_500_feet * 100, 2)}%)')
# Out:
# The number of trips under 1 mile is 392076 (69.33%)
# The number of trips 1 mile or more is 173446 (30.67%)
# The number of trips under 500 feet is 148503 (26.26%)

# %% [markdown]
# <h3>Base Map Template</h3>

# %% [markdown]
# <h4>Here, we are plotting the public transportation stops.</h4>

# %%
# Dropping all unnecessary columns in the bus stops dataframe
bus_stops_df = bus_stops_df.drop(columns=['Stop ID Number', 'Stop Abbreviation', 'Bench', 'Shelter'])

# Split out the Mapped Location column into latitude and longitude columns
# We need to drop the opening and closing parentheses and then split on the comma
bus_stops_df['Mapped Location'] = bus_stops_df['Mapped Location'].str.replace('(', '')
bus_stops_df['Mapped Location'] = bus_stops_df['Mapped Location'].str.replace(')', '')
bus_stops_df[['latitude', 'longitude']] = bus_stops_df['Mapped Location'].str.split(',', expand=True)

# Dropping the now unnecessary 'Mapped Location' column
bus_stops_df = bus_stops_df.drop(columns=['Mapped Location'])

# %% [markdown]
# <h4>Now we want to add the scooter data to the map where the trip started within 1 mile of a bus stop and the duration was less than 1 mile.</h4>

# %%
# Build constants for the bus stop radius so that we increase/decrease the radius based on the number of bus stops
# Then, use a round function to round the radius to constant value
BUS_STOP_BEGIN_TRIP_RADIUS = 0.25

# %%
# First, we need to get the bus stop coordinates into a list of tuples and cast each value to a float
bus_stop_coordinates = list(zip(bus_stops_df['latitude'].astype(float), bus_stops_df['longitude'].astype(float)))

# Now we need to get the scooter data that meets our criteria by looping over the dataframe and comparing each row to the bus stop coordinates

# Declare an empty dataframe
last_mile_df = pd.DataFrame(columns=trips_under_1_mile_df.columns)

# Loop over all of the under 1 mile trips
loop_count = 0
for index, row in trips_under_1_mile_df.iterrows():
    scooter_coordinates = (row['startlatitude'], row['startlongitude'])

    # Loop over bus stop coordinates and compare to starting trip coordinates
    for bus_stop_co in bus_stop_coordinates:
        # Distance is in miles
        start_distance_from_bus_stop = shortest_distance(scooter_coordinates[0], scooter_coordinates[1], bus_stop_co[0], bus_stop_co[1])

        if start_distance_from_bus_stop < BUS_STOP_BEGIN_TRIP_RADIUS:
            # Add the row to the dataframe
            last_mile_df = pd.concat([last_mile_df, pd.DataFrame([row])], ignore_index=True)
            break

    loop_count += 1

    # avoid an infinite loop
    if loop_count > len(trips_under_1_mile_df):
        break

    # Debug only below
    if loop_count % 1000 == 0:
        print(f'Loop count: {loop_count}')
# Out:
# Loop count: 1000
# Loop count: 2000
# Loop count: 3000
# Loop count: 4000
# Loop count: 5000
# Loop count: 6000
# Loop count: 7000
# Loop count: 8000
# Loop count: 9000
# Loop count: 10000
# Loop count: 11000
# Loop count: 12000
# Loop count: 13000
# Loop count: 14000
# Loop count: 15000
# Loop count: 16000
# Loop count: 17000
# Loop count: 18000
# Loop count: 19000
# Loop count: 20000
# Loop count: 21000
# Loop count: 22000
# Loop count: 23000
# Loop count: 24000
# Loop count: 25000
# Loop count: 26000
# Loop count: 27000
# Loop count: 28000
# Loop count: 29000
# Loop count: 30000
# Loop count: 31000
# Loop count: 32000
# Loop count: 33000
# Loop count: 34000
# Loop count: 35000
# Loop count: 36000
# Loop count: 37000
# Loop count: 38000
# Loop count: 39000
# Loop count: 40000
# Loop count: 41000
# Loop count: 42000
# Loop count: 43000
# Loop count: 44000
# Loop count: 45000
# Loop count: 46000
# Loop count: 47000
# Loop count: 48000
# Loop count: 49000
# Loop count: 50000
# Loop count: 51000
# Loop count: 52000
# Loop count: 53000
# Loop count: 54000
# Loop count: 55000
# Loop count: 56000
# Loop count: 57000
# Loop count: 58000
# Loop count: 59000
# Loop count: 60000
# Loop count: 61000
# Loop count: 62000
# Loop count: 63000
# Loop count: 64000
# Loop count: 65000
# Loop count: 66000
# Loop count: 67000
# Loop count: 68000
# Loop count: 69000
# Loop count: 70000
# Loop count: 71000
# Loop count: 72000
# Loop count: 73000
# Loop count: 74000
# Loop count: 75000
# Loop count: 76000
# Loop count: 77000
# Loop count: 78000
# Loop count: 79000
# Loop count: 80000
# Loop count: 81000
# Loop count: 82000
# Loop count: 83000
# Loop count: 84000
# Loop count: 85000
# Loop count: 86000
# Loop count: 87000
# Loop count: 88000
# Loop count: 89000
# Loop count: 90000
# Loop count: 91000
# Loop count: 92000
# Loop count: 93000
# Loop count: 94000
# Loop count: 95000
# Loop count: 96000
# Loop count: 97000
# Loop count: 98000
# Loop count: 99000
# Loop count: 100000
# Loop count: 101000
# Loop count: 102000
# Loop count: 103000
# Loop count: 104000
# Loop count: 105000
# Loop count: 106000
# Loop count: 107000
# Loop count: 108000
# Loop count: 109000
# Loop count: 110000
# Loop count: 111000
# Loop count: 112000
# Loop count: 113000
# Loop count: 114000
# Loop count: 115000
# Loop count: 116000
# Loop count: 117000
# Loop count: 118000
# Loop count: 119000
# Loop count: 120000
# Loop count: 121000
# Loop count: 122000
# Loop count: 123000
# Loop count: 124000
# Loop count: 125000
# Loop count: 126000
# Loop count: 127000
# Loop count: 128000
# Loop count: 129000
# Loop count: 130000
# Loop count: 131000
# Loop count: 132000
# Loop count: 133000
# Loop count: 134000
# Loop count: 135000
# Loop count: 136000
# Loop count: 137000
# Loop count: 138000
# Loop count: 139000
# Loop count: 140000
# Loop count: 141000
# Loop count: 142000
# Loop count: 143000
# Loop count: 144000
# Loop count: 145000
# Loop count: 146000
# Loop count: 147000
# Loop count: 148000
# Loop count: 149000
# Loop count: 150000
# Loop count: 151000
# Loop count: 152000
# Loop count: 153000
# Loop count: 154000
# Loop count: 155000
# Loop count: 156000
# Loop count: 157000
# Loop count: 158000
# Loop count: 159000
# Loop count: 160000
# Loop count: 161000
# Loop count: 162000
# Loop count: 163000
# Loop count: 164000
# Loop count: 165000
# Loop count: 166000
# Loop count: 167000
# Loop count: 168000
# Loop count: 169000
# Loop count: 170000
# Loop count: 171000
# Loop count: 172000
# Loop count: 173000
# Loop count: 174000
# Loop count: 175000
# Loop count: 176000
# Loop count: 177000
# Loop count: 178000
# Loop count: 179000
# Loop count: 180000
# Loop count: 181000
# Loop count: 182000
# Loop count: 183000
# Loop count: 184000
# Loop count: 185000
# Loop count: 186000
# Loop count: 187000
# Loop count: 188000
# Loop count: 189000
# Loop count: 190000
# Loop count: 191000
# Loop count: 192000
# Loop count: 193000
# Loop count: 194000
# Loop count: 195000
# Loop count: 196000
# Loop count: 197000
# Loop count: 198000
# Loop count: 199000
# Loop count: 200000
# Loop count: 201000
# Loop count: 202000
# Loop count: 203000
# Loop count: 204000
# Loop count: 205000
# Loop count: 206000
# Loop count: 207000
# Loop count: 208000
# Loop count: 209000
# Loop count: 210000
# Loop count: 211000
# Loop count: 212000
# Loop count: 213000
# Loop count: 214000
# Loop count: 215000
# Loop count: 216000
# Loop count: 217000
# Loop count: 218000
# Loop count: 219000
# Loop count: 220000
# Loop count: 221000
# Loop count: 222000
# Loop count: 223000
# Loop count: 224000
# Loop count: 225000
# Loop count: 226000
# Loop count: 227000
# Loop count: 228000
# Loop count: 229000
# Loop count: 230000
# Loop count: 231000
# Loop count: 232000
# Loop count: 233000
# Loop count: 234000
# Loop count: 235000
# Loop count: 236000
# Loop count: 237000
# Loop count: 238000
# Loop count: 239000
# Loop count: 240000
# Loop count: 241000
# Loop count: 242000
# Loop count: 243000
# Loop count: 244000
# Loop count: 245000
# Loop count: 246000
# Loop count: 247000
# Loop count: 248000
# Loop count: 249000
# Loop count: 250000
# Loop count: 251000
# Loop count: 252000
# Loop count: 253000
# Loop count: 254000
# Loop count: 255000
# Loop count: 256000
# Loop count: 257000
# Loop count: 258000
# Loop count: 259000
# Loop count: 260000
# Loop count: 261000
# Loop count: 262000
# Loop count: 263000
# Loop count: 264000
# Loop count: 265000
# Loop count: 266000
# Loop count: 267000
# Loop count: 268000
# Loop count: 269000
# Loop count: 270000
# Loop count: 271000
# Loop count: 272000
# Loop count: 273000
# Loop count: 274000
# Loop count: 275000
# Loop count: 276000
# Loop count: 277000
# Loop count: 278000
# Loop count: 279000
# Loop count: 280000
# Loop count: 281000
# Loop count: 282000
# Loop count: 283000
# Loop count: 284000
# Loop count: 285000
# Loop count: 286000
# Loop count: 287000
# Loop count: 288000
# Loop count: 289000
# Loop count: 290000
# Loop count: 291000
# Loop count: 292000
# Loop count: 293000
# Loop count: 294000
# Loop count: 295000
# Loop count: 296000
# Loop count: 297000
# Loop count: 298000
# Loop count: 299000
# Loop count: 300000
# Loop count: 301000
# Loop count: 302000
# Loop count: 303000
# Loop count: 304000
# Loop count: 305000
# Loop count: 306000
# Loop count: 307000
# Loop count: 308000
# Loop count: 309000
# Loop count: 310000
# Loop count: 311000
# Loop count: 312000
# Loop count: 313000
# Loop count: 314000
# Loop count: 315000
# Loop count: 316000
# Loop count: 317000
# Loop count: 318000
# Loop count: 319000
# Loop count: 320000
# Loop count: 321000
# Loop count: 322000
# Loop count: 323000
# Loop count: 324000
# Loop count: 325000
# Loop count: 326000
# Loop count: 327000
# Loop count: 328000
# Loop count: 329000
# Loop count: 330000
# Loop count: 331000
# Loop count: 332000
# Loop count: 333000
# Loop count: 334000
# Loop count: 335000
# Loop count: 336000
# Loop count: 337000
# Loop count: 338000
# Loop count: 339000
# Loop count: 340000
# Loop count: 341000
# Loop count: 342000
# Loop count: 343000
# Loop count: 344000
# Loop count: 345000
# Loop count: 346000
# Loop count: 347000
# Loop count: 348000
# Loop count: 349000
# Loop count: 350000
# Loop count: 351000
# Loop count: 352000
# Loop count: 353000
# Loop count: 354000
# Loop count: 355000
# Loop count: 356000
# Loop count: 357000
# Loop count: 358000
# Loop count: 359000
# Loop count: 360000
# Loop count: 361000
# Loop count: 362000
# Loop count: 363000
# Loop count: 364000
# Loop count: 365000
# Loop count: 366000
# Loop count: 367000
# Loop count: 368000
# Loop count: 369000
# Loop count: 370000
# Loop count: 371000
# Loop count: 372000
# Loop count: 373000
# Loop count: 374000
# Loop count: 375000
# Loop count: 376000
# Loop count: 377000
# Loop count: 378000
# Loop count: 379000
# Loop count: 380000
# Loop count: 381000
# Loop count: 382000
# Loop count: 383000
# Loop count: 384000
# Loop count: 385000
# Loop count: 386000
# Loop count: 387000
# Loop count: 388000
# Loop count: 389000
# Loop count: 390000
# Loop count: 391000
# Loop count: 392000
#              pubtimestamp companyname triprecordnum        sumdid
# 0 2019-05-01 00:05:55.570        Bird       BRD2167  PoweredEJF1K  \
# 1 2019-05-01 00:10:56.013        Bird       BRD2193  PoweredSX2AW
# 2 2019-05-01 00:10:56.013        Bird       BRD2191  PoweredVS299
# 3 2019-05-01 00:10:56.013        Bird       BRD2197  Powered5R8S1
# 4 2019-05-01 00:10:56.013        Bird       BRD2196  PoweredF8GJP
#
#    tripduration  tripdistance   startdate        starttime     enddate
# 0           3.0       984.252  2019-05-01  00:03:56.546666  2019-05-01  \
# 1           6.0      2624.672  2019-05-01  00:06:34.436666  2019-05-01
# 2           3.0       984.252  2019-05-01  00:09:14.073333  2019-05-01
# 3           9.0      3280.840  2019-05-01  00:01:50.923333  2019-05-01
# 4           9.0       328.084  2019-05-01  00:03:32.563333  2019-05-01
#
#            endtime  startlatitude  startlongitude  endlatitude  endlongitude
# 0  00:06:45.786666        36.1544        -86.7862      36.1515      -86.7844  \
# 1  00:12:48.676666        36.1708        -86.7893      36.1746      -86.7860
# 2  00:12:37.533333        36.1612        -86.7808      36.1593      -86.7808
# 3  00:11:03.403333        36.1614        -86.7760      36.1567      -86.7808
# 4  00:12:36.373333        36.1647        -86.7809      36.1641      -86.7830
#
#                                            triproute               create_dt
# 0  [(36.154368, -86.785909), (36.151689, -86.7843... 2019-05-02 05:30:24.317
# 1  [(36.170995, -86.789593), (36.173193, -86.7912... 2019-05-02 05:30:24.833
# 2  [(36.160907, -86.780775), (36.159377, -86.7807... 2019-05-02 05:30:24.663
# 3  [(36.161623, -86.776131), (36.161411, -86.7760... 2019-05-02 05:30:25.087
# 4  [(36.165052, -86.78149), (36.164572, -86.78154... 2019-05-02 05:30:25.027

# %% [markdown]
# <h4>The short trips that started near the bus stops have been compiled. Now, we will cluster plot them onto the base map.</h4>

# %%
print(last_mile_df.head())
# Out:
#              pubtimestamp companyname triprecordnum        sumdid
# 0 2019-05-01 00:05:55.570        Bird       BRD2167  PoweredEJF1K  \
# 1 2019-05-01 00:10:56.013        Bird       BRD2193  PoweredSX2AW
# 2 2019-05-01 00:10:56.013        Bird       BRD2191  PoweredVS299
# 3 2019-05-01 00:10:56.013        Bird       BRD2197  Powered5R8S1
# 4 2019-05-01 00:10:56.013        Bird       BRD2196  PoweredF8GJP
#
#    tripduration  tripdistance   startdate        starttime     enddate
# 0           3.0       984.252  2019-05-01  00:03:56.546666  2019-05-01  \
# 1           6.0      2624.672  2019-05-01  00:06:34.436666  2019-05-01
# 2           3.0       984.252  2019-05-01  00:09:14.073333  2019-05-01
# 3           9.0      3280.840  2019-05-01  00:01:50.923333  2019-05-01
# 4           9.0       328.084  2019-05-01  00:03:32.563333  2019-05-01
#
#            endtime  startlatitude  startlongitude  endlatitude  endlongitude
# 0  00:06:45.786666        36.1544        -86.7862      36.1515      -86.7844  \
# 1  00:12:48.676666        36.1708        -86.7893      36.1746      -86.7860
# 2  00:12:37.533333        36.1612        -86.7808      36.1593      -86.7808
# 3  00:11:03.403333        36.1614        -86.7760      36.1567      -86.7808
# 4  00:12:36.373333        36.1647        -86.7809      36.1641      -86.7830
#
#                                            triproute               create_dt
# 0  [(36.154368, -86.785909), (36.151689, -86.7843... 2019-05-02 05:30:24.317
# 1  [(36.170995, -86.789593), (36.173193, -86.7912... 2019-05-02 05:30:24.833
# 2  [(36.160907, -86.780775), (36.159377, -86.7807... 2019-05-02 05:30:24.663
# 3  [(36.161623, -86.776131), (36.161411, -86.7760... 2019-05-02 05:30:25.087
# 4  [(36.165052, -86.78149), (36.164572, -86.78154... 2019-05-02 05:30:25.027

# %%
# Initial boilerplate code for the map
base_map = folium.Map(
    location=[36.1627, -86.7816],
    zoom_start=12
)

# Create marker clusters
bus_stop_marker_cluster = MarkerCluster().add_to(base_map)
scooter_marker_cluster = MarkerCluster().add_to(base_map)

# Add bus stop markers to the map
for index, row in bus_stops_df.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=row['Stop Name'],
        icon=folium.Icon(color='blue', icon='bus', prefix='fa')
    ).add_to(bus_stop_marker_cluster)

# Add scooter markers to the map
for index, row in last_mile_df.iterrows():
    folium.Marker(
        location=[row['endlatitude'], row['endlongitude']],
        popup=str(row['enddate']) + ' : ' + row['triprecordnum'],
        icon=folium.Icon(color='green', icon='bolt', prefix='fa')
    ).add_to(scooter_marker_cluster)

# Save an interactive HTML map
base_map.save('../maps/last_mile_trip_map.html')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 23
#      19 # Add scooter markers to the map
#      20 for index, row in last_mile_df.iterrows():
#      21     folium.Marker(
#      22         location=[row['endlatitude'], row['endlongitude']],
# ---> 23         popup=row['enddate'].toStr() + ' : ' + row['triprecordnum'],
#      24         icon=folium.Icon(color='green', icon='bolt', prefix='fa')
#      25     ).add_to(scooter_marker_cluster)
#      27 # Save an interactive HTML map
#      28 base_map.save('../maps/last_mile_trip_map.html')
#
# AttributeError: 'datetime.date' object has no attribute 'toStr'
